# %%
import sys
sys.path.insert(0, '/Users/alamf/1Jupyter/current_projects/vff_tn_v2')
from nodewise_train import *

# %% [markdown]
# # 6 qubit jobs

# %%
num_qubits = 6
t=0.1
num_trotter_steps = 5

# %%
# jobs a64 and b64
num_w_layers = 6
nodewise_train(num_qubits, t, num_trotter_steps, num_w_layers, num_stack_sweeps=1, max_dim=64)
# Out:
# KeyboardInterrupt

# %%
# jobs a32 and b32
num_w_layers = 6
nodewise_train(num_qubits, t, num_trotter_steps, num_w_layers, num_stack_sweeps=1, max_dim=32)
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 13/13 [00:29<00:00,  2.29s/it]
#
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [01:02<00:00, 62.20s/it]
# 0.04696794391209402
# ([0.04909756325769399,
#   0.04909754595036908,
#   0.049063649954825816,
#   0.049061729285806654,
#   0.04904381942639047,
#   0.04903217374200031,
#   0.04902541211933187,
#   0.04902468679917471,
#   0.04901187789686445,
#   0.049011870937706314,
#   0.049010672975698166,
#   0.04901067027049377,
#   0.04900583845293438,
#   0.04900556575692483,
#   0.049003006900364854,
#   0.0489986159169753,
#   0.04899764979935961,
#   0.048997546853222884,
#   0.04899572164802324,
#   0.04899572059396318,
#   0.048995273442434595,
#   0.048995273025822295,
#   0.04899458479145369,
#   0.04899454608365539,
#   0.0489941806396883,
#   0.04899252459843595,
#   0.04899238659785454,
#   0.04899237199070838,
#   0.04899211211729537,
# ...

# %%
# jobs a20 and b20
num_w_layers = 6
nodewise_train(num_qubits, t, num_trotter_steps, num_w_layers, num_stack_sweeps=1, max_dim=20)
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 13/13 [00:13<00:00,  1.02s/it]
#
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:28<00:00, 28.63s/it]
# 0.04573246141855214
# ([0.049157390713794546,
#   0.04915737698994649,
#   0.04914960872072216,
#   0.04914815459214139,
#   0.049036753148572254,
#   0.04903648644438252,
#   0.04899443847213947,
#   0.04899389064334936,
#   0.04899095579250834,
#   0.04899095076032467,
#   0.048988042627316486,
#   0.04898804070459295,
#   0.04898692896624768,
#   0.04898672173778684,
#   0.04897085277225077,
#   0.048970752944054174,
#   0.04896476387291726,
#   0.0489646858502375,
#   0.04896426599438142,
#   0.048964265287927855,
#   0.048963164652790825,
#   0.04896316438033299,
#   0.04896300497338668,
#   0.04896297543730743,
#   0.04896071539016744,
#   0.04896067789549896,
#   0.048959824972284904,
#   0.04895981385542669,
#   0.04895975365263305,
# ...

# %%
# job c32
num_w_layers = 4
nodewise_train(num_qubits, t, num_trotter_steps, num_w_layers, num_stack_sweeps=1, max_dim=32)
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:16<00:00,  1.81s/it]
#
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:37<00:00, 37.17s/it]
# 0.043749074045156044
# ([0.049095882371343214,
#   0.049044092874030776,
#   0.04901854682689166,
#   0.049001148624603585,
#   0.04889578134757899,
#   0.048895548152453894,
#   0.048855783281037235,
#   0.04884921297841882,
#   0.04883945520054089,
#   0.048820001110086,
#   0.04880799590106899,
#   0.04880067132921306,
#   0.04879700526747399,
#   0.04879452976125942,
#   0.04877950308704937,
#   0.04877941646229211,
#   0.048773746325730505,
#   0.0487728119840074,
#   0.048771412649272206,
#   0.048768662993478706,
#   0.048764155989051816,
#   0.04876312226781754,
#   0.04876259670096528,
#   0.04876224452184075,
#   0.04876010302312783,
#   0.04876007064375798,
#   0.04875926260824048,
#   0.04875912970915719,
#   0.04875892914082447,
# ...

# %%
# job c20
num_w_layers = 4
nodewise_train(num_qubits, t, num_trotter_steps, num_w_layers, num_stack_sweeps=1, max_dim=20)
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:08<00:00,  1.06it/s]
#
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:18<00:00, 18.66s/it]
# 0.044636270152036195
# ([0.048982603121868085,
#   0.04881403051140798,
#   0.04880325057632051,
#   0.04880224291255675,
#   0.04879568212396701,
#   0.048788100602494944,
#   0.048785625957133316,
#   0.04878524953652863,
#   0.04878118734560721,
#   0.04871756120307058,
#   0.0487019196237215,
#   0.048677906546731986,
#   0.04867637862212959,
#   0.048676234348399516,
#   0.04867529372633117,
#   0.048672437807411595,
#   0.048672083155447354,
#   0.04867202952062888,
#   0.04867145342324064,
#   0.04866239208440759,
#   0.048656483548533136,
#   0.04865306357813526,
#   0.04865284652491808,
#   0.04865282604443921,
#   0.04865269129602978,
#   0.04865161547207353,
#   0.04865156468915777,
#   0.048651557134570256,
# ...

# %%
# job a starts from non identity D with 6 layers
# job b starts from identity D with 6 layers
# job c starts from identity D with 4 layers 
# trying to figure out how many stack_sweeps I can fit in within 16 hours on the cluster

# %% [markdown]
# # 8 qubit jobs

# %%
num_qubits = 8
t=0.1
num_trotter_steps = 5

# %%
# job a100
num_w_layers = 8
nodewise_train(num_qubits, t, num_trotter_steps, num_w_layers, num_stack_sweeps=1, max_dim=100)
# Out:
# ...
#   0%|                                                                                           | 0/17 [00:00<?, ?it/s]WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
#
# ...
#  41%|█████████████████████████████████▊                                                | 7/17 [19:11<46:30, 279.07s/it]

# %%
# job a64
num_w_layers = 8
nodewise_train(num_qubits, t, num_trotter_steps, num_w_layers, num_stack_sweeps=1, max_dim=64)

# %%
# job a32 
num_w_layers = 8
nodewise_train(num_qubits, t, num_trotter_steps, num_w_layers, num_stack_sweeps=1, max_dim=32)
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 17/17 [03:16<00:00, 11.57s/it]
#
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [07:13<00:00, 433.61s/it]
# 0.062125392001558866
# ([0.48225109407282396,
#   0.4822152021528716,
#   0.48217609319761057,
#   0.48217601894617823,
#   0.48217600008901584,
#   0.48217599627492314,
#   0.4819789873598421,
#   0.4819672671748566,
#   0.4818521173755388,
#   0.48185203691307954,
#   0.48185201503818953,
#   0.4818519673861792,
#   0.48182882593896315,
#   0.4818084042382502,
#   0.4817937357692845,
#   0.4817822475367133,
#   0.48176819993999787,
#   0.4817681686934904,
#   0.4817681573928856,
#   0.48176811129038755,
#   0.48170028627946926,
#   0.48169518806151346,
#   0.48165561805155543,
#   0.48165552673435297,
#   0.4816555153148071,
#   0.4816554953012435,
#   0.48164719280924295,
#   0.48164067618305895,
#   0.48163219328774076,
# ...

# %%
# job b100
num_w_layers = 6
nodewise_train(num_qubits, t, num_trotter_steps, num_w_layers, num_stack_sweeps=1, max_dim=100)

# %%
# job b64
num_w_layers = 6
nodewise_train(num_qubits, t, num_trotter_steps, num_w_layers, num_stack_sweeps=1, max_dim=64)

# %%
# job b32 
num_w_layers = 6
nodewise_train(num_qubits, t, num_trotter_steps, num_w_layers, num_stack_sweeps=1, max_dim=32)
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 13/13 [02:17<00:00, 10.60s/it]
#
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [05:04<00:00, 304.36s/it]
# 0.05887502608523598
# ([0.6631350756227364,
#   0.6631350722787323,
#   0.6631332575897624,
#   0.6631331866454302,
#   0.6631305075397025,
#   0.6630326385291098,
#   0.6630322652327063,
#   0.6628318738891358,
#   0.6628316653067212,
#   0.662770008867672,
#   0.6627680297357261,
#   0.6627679773035624,
#   0.6627666829432382,
#   0.6627666804003284,
#   0.6626823811593162,
#   0.6626823800249744,
#   0.6626814503288965,
#   0.6626814122090923,
#   0.6626800166032004,
#   0.6626361432741193,
#   0.662636057583253,
#   0.6625047082091895,
#   0.6625046684224881,
#   0.6624777705217553,
#   0.6624767391825919,
#   0.6624767110605727,
#   0.6624760478737679,
#   0.6624760471793257,
#   0.6624157256332978,
#   0.6624157181095024,
# ...

# %%
# job c64
num_w_layers = 4
nodewise_train(num_qubits, t, num_trotter_steps, num_w_layers, num_stack_sweeps=1, max_dim=64)

# %%
# job c32 
num_w_layers = 4
nodewise_train(num_qubits, t, num_trotter_steps, num_w_layers, num_stack_sweeps=1, max_dim=32)
# Out:
# ...
#   0%|                                                                                            | 0/9 [00:00<?, ?it/s]WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
#
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [01:15<00:00,  8.40s/it]
#
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [02:56<00:00, 176.18s/it]
# 0.057690243756365334
# ([0.13068421428619448,
#   0.1306745260793155,
#   0.13058462342763977,
#   0.13057536829899696,
#   0.1305660982605127,
#   0.1305313002637134,
#   0.13021793423334027,
#   0.1302114412689772,
#   0.13008111152017554,
#   0.13006768307400407,
#   0.13006387025048016,
#   0.13006017144042725,
#   0.13002298015053837,
#   0.1300189823240221,
#   0.12994482304113197,
#   0.12994333229140587,
#   0.12992802346859222,
#   0.1299264944635874,
#   0.12992490911456334,
#   0.12991940755319686,
# ...
